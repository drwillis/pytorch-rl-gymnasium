# %% [markdown]
# https://www.freecodecamp.org/news/an-intro-to-advantage-actor-critic-methods-lets-play-sonic-the-hedgehog-86d6240171d/
# https://towardsdatascience.com/understanding-actor-critic-methods-931b97b6df3f
# http://rail.eecs.berkeley.edu/deeprlcourse-fa17/f17docs/lecture_5_actor_critic_pdf.pdf
# https://danieltakeshi.github.io/2017/03/28/going-deeper-into-reinforcement-learning-fundamentals-of-policy-gradients/
# https://danieltakeshi.github.io/2018/06/28/a2c-a3c/
# https://danieltakeshi.github.io/2017/04/02/notes-on-the-generalized-advantage-estimation-paper/
# https://github.com/ikostrikov/pytorch-a2c-ppo-acktr-gail/blob/master/a2c_ppo_acktr/algo/a2c_acktr.py
# https://github.com/higgsfield/RL-Adventure-2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions

import matplotlib.pyplot as plt
import numpy as np
import random
import gymnasium as gym

# %%
# ----------------------------
# Device setup
# ----------------------------
def get_device():
    """Select available device (CUDA, MPS for Apple, or CPU)."""
    if torch.cuda.is_available():
        device = torch.device("cuda")
    elif torch.backends.mps.is_available():  # macOS Metal
        device = torch.device("mps")
    elif torch.version.hip is not None and torch.cuda.is_available():
        device = torch.device("cuda")  # AMD ROCm usually appears as CUDA device
    else:
        device = torch.device("cpu")
    print(f"Using device: {device}")
    return device

# %%
# ----------------------------
# Seeding for reproducibility
# ----------------------------
def set_seed(seed):
    """Sets seed for reproducibility across libraries and devices."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout = 0.5):
        super().__init__()
        self.fc_1 = nn.Linear(input_dim, hidden_dim)
        self.fc_2 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        x = self.fc_1(x)
        x = self.dropout(x)
        x = F.relu(x)
        x = self.fc_2(x)
        return x

# %%
class ActorCritic(nn.Module):
    def __init__(self, actor, critic):
        super().__init__()
        self.actor = actor
        self.critic = critic
        
    def forward(self, state):
        action_pred = self.actor(state)
        value_pred = self.critic(state)
        return action_pred, value_pred

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        if m.bias is not None:
            m.bias.data.zero_()

# %%
def train_episode(env, policy, optimizer, gamma, device):
    """Train policy for one episode."""    
    policy.train()
    log_prob_actions, rewards, values = [], [], []
    done = False
    state, _ = env.reset()  # Gymnasium returns (obs, info)
    while not done:
        state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        action_pred, value_pred = policy(state_tensor)               
        action_prob = F.softmax(action_pred, dim = -1)
        dist = distributions.Categorical(action_prob)
        action = dist.sample()
        
        next_state, reward, done, truncated, _ = env.step(action.item())
        done = done or truncated

        log_prob_actions.append(dist.log_prob(action))
        rewards.append(reward)
        values.append(value_pred)
        state = next_state
    
    log_prob_actions = torch.stack(log_prob_actions)
    values = torch.cat(values).squeeze(-1)
    returns = calculate_returns(rewards, gamma, device, True)
    advantages = calculate_advantages(returns, values, True)    
    policy_loss, value_loss = update_policy(advantages, log_prob_actions, returns, values, optimizer)

    return policy_loss, value_loss, sum(rewards)

# %%
# ----------------------------
# Training and evaluation
# ----------------------------
def calculate_returns(rewards, gamma, device, normalize=True):
    """Compute discounted returns for an episode."""
    returns = []
    R = 0
    for r in reversed(rewards):
        R = r + gamma * R
        returns.insert(0, R)
    returns = torch.tensor(returns, dtype=torch.float32, device=device)
    if normalize:
        returns = (returns - returns.mean()) / (returns.std() + 1e-8)
    return returns

# %%
def calculate_advantages(returns, values, normalize = True):
    advantages = returns - values.detach()
    if normalize:
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
    return advantages

# %%
def update_policy(advantages, log_prob_actions, returns, values, optimizer): 
    """Compute loss and update policy and value parameters."""
    # advantages = advantages.detach()
    # returns = returns.detach()
    policy_loss = -(advantages * log_prob_actions).sum()
    value_loss = F.smooth_l1_loss(values, returns)
    optimizer.zero_grad()
    value_coef = 1
    if True:
        entropy_coef = 1
        # Optional entropy regularization for exploration
        loss = policy_loss + value_coef * value_loss - entropy_coef * (-log_prob_actions).mean()
    else:
        loss = policy_loss + value_coef * value_loss
    loss.backward()
    optimizer.step()
    return policy_loss.item(), value_loss.item()

# %%
def evaluate(env, policy, device):
    """Evaluate policy (greedy)."""    
    policy.eval()
    done = False
    total_reward = 0
    state, _ = env.reset()

    while not done:
        state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        with torch.no_grad():
            action_logits, _ = policy(state_tensor)
            action = torch.argmax(F.softmax(action_logits, dim=-1)).item()
        next_state, reward, done, truncated, _ = env.step(action)
        done = done or truncated
        total_reward += reward
        state = next_state

    return total_reward

# %%
# ----------------------------
# Main experiment
# ----------------------------
train_env = gym.make('CartPole-v1')
test_env = gym.make('CartPole-v1')

SEED = 1234
set_seed(SEED)
train_env.reset(seed=SEED) # Seed the environment upon reset
test_env.reset(seed=SEED+1) # Seed the environment upon reset

device_ = get_device()
# device_ = torch.device("cpu")

INPUT_DIM = train_env.observation_space.shape[0]
HIDDEN_DIM = 128
OUTPUT_DIM = test_env.action_space.n

actor = MLP(INPUT_DIM, HIDDEN_DIM, OUTPUT_DIM)
critic = MLP(INPUT_DIM, HIDDEN_DIM, 1)

policy_ = ActorCritic(actor, critic).to(device_)
policy_.apply(init_weights)

LEARNING_RATE = 0.01
optimizer_ = optim.Adam(policy_.parameters(), lr = LEARNING_RATE)

MAX_EPISODES = 1000
DISCOUNT_FACTOR = 0.99
N_TRIALS = 25
REWARD_THRESHOLD = 475
PRINT_EVERY = 10

train_rewards = []
test_rewards = []

for episode in range(1, MAX_EPISODES+1):
    
    policy_loss, value_loss, train_reward = train_episode(train_env, policy_, optimizer_, DISCOUNT_FACTOR, device_)
    
    test_reward = evaluate(test_env, policy_, device_)
    
    train_rewards.append(train_reward)
    test_rewards.append(test_reward)
    
    mean_train_rewards = np.mean(train_rewards[-N_TRIALS:])
    mean_test_rewards = np.mean(test_rewards[-N_TRIALS:])
    
    if episode % PRINT_EVERY == 0: 
        print(f'| Episode: {episode:3} | Mean Train Rewards: {mean_train_rewards:5.1f} | Mean Test Rewards: {mean_test_rewards:5.1f} |')
    
    if mean_test_rewards >= REWARD_THRESHOLD and episode > 3*PRINT_EVERY:
        print(f'Reached reward threshold in {episode} episodes')
        break
print(f'| Episode: {episode:3} | Mean Train Rewards: {mean_train_rewards:5.1f} | Mean Test Rewards: {mean_test_rewards:5.1f} |')
# Out:
# Using device: cuda
# | Episode:  10 | Mean Train Rewards:  19.3 | Mean Test Rewards:   9.2 |
# | Episode:  20 | Mean Train Rewards:  18.5 | Mean Test Rewards:   9.4 |
# | Episode:  30 | Mean Train Rewards:  17.2 | Mean Test Rewards:   9.8 |
# | Episode:  40 | Mean Train Rewards:  22.4 | Mean Test Rewards:  18.7 |
# | Episode:  50 | Mean Train Rewards:  31.4 | Mean Test Rewards:  53.6 |
# | Episode:  60 | Mean Train Rewards:  42.4 | Mean Test Rewards:  73.4 |
# | Episode:  70 | Mean Train Rewards:  47.4 | Mean Test Rewards:  77.8 |
# | Episode:  80 | Mean Train Rewards:  54.2 | Mean Test Rewards:  54.4 |
# | Episode:  90 | Mean Train Rewards:  51.2 | Mean Test Rewards:  40.1 |
# | Episode: 100 | Mean Train Rewards:  34.6 | Mean Test Rewards:  33.2 |
# | Episode: 110 | Mean Train Rewards:  30.9 | Mean Test Rewards:  31.1 |
# | Episode: 120 | Mean Train Rewards:  35.4 | Mean Test Rewards:  41.4 |
# | Episode: 130 | Mean Train Rewards:  44.8 | Mean Test Rewards:  70.9 |
# | Episode: 140 | Mean Train Rewards:  54.8 | Mean Test Rewards:  72.9 |
# | Episode: 150 | Mean Train Rewards:  47.7 | Mean Test Rewards:  52.3 |
# | Episode: 160 | Mean Train Rewards:  44.0 | Mean Test Rewards:  63.8 |
# | Episode: 170 | Mean Train Rewards:  32.1 | Mean Test Rewards:  89.8 |
# | Episode: 180 | Mean Train Rewards:  31.4 | Mean Test Rewards: 126.2 |
# | Episode: 190 | Mean Train Rewards:  34.2 | Mean Test Rewards:  96.5 |
# | Episode: 200 | Mean Train Rewards:  36.1 | Mean Test Rewards:  89.2 |
# | Episode: 210 | Mean Train Rewards:  37.6 | Mean Test Rewards:  67.9 |
# | Episode: 220 | Mean Train Rewards:  36.7 | Mean Test Rewards:  50.1 |
# | Episode: 230 | Mean Train Rewards:  40.4 | Mean Test Rewards:  46.0 |
# | Episode: 240 | Mean Train Rewards:  48.6 | Mean Test Rewards:  52.2 |
# | Episode: 250 | Mean Train Rewards:  59.1 | Mean Test Rewards:  62.2 |
# | Episode: 260 | Mean Train Rewards:  63.7 | Mean Test Rewards:  69.4 |
# | Episode: 270 | Mean Train Rewards:  58.9 | Mean Test Rewards:  70.0 |
# | Episode: 280 | Mean Train Rewards:  59.3 | Mean Test Rewards:  97.0 |
# | Episode: 290 | Mean Train Rewards:  63.4 | Mean Test Rewards: 160.6 |
# | Episode: 300 | Mean Train Rewards:  66.9 | Mean Test Rewards: 214.4 |
# | Episode: 310 | Mean Train Rewards:  68.8 | Mean Test Rewards: 214.8 |
# | Episode: 320 | Mean Train Rewards:  65.9 | Mean Test Rewards: 142.8 |
# | Episode: 330 | Mean Train Rewards:  63.0 | Mean Test Rewards: 130.4 |
# | Episode: 340 | Mean Train Rewards:  52.8 | Mean Test Rewards: 116.8 |
# | Episode: 350 | Mean Train Rewards:  57.3 | Mean Test Rewards:  85.1 |
# | Episode: 360 | Mean Train Rewards:  54.8 | Mean Test Rewards:  73.8 |
# | Episode: 370 | Mean Train Rewards:  58.2 | Mean Test Rewards: 103.4 |
# | Episode: 380 | Mean Train Rewards:  59.0 | Mean Test Rewards: 111.4 |
# | Episode: 390 | Mean Train Rewards:  54.0 | Mean Test Rewards: 101.0 |
# | Episode: 400 | Mean Train Rewards:  51.2 | Mean Test Rewards:  73.7 |
# | Episode: 410 | Mean Train Rewards:  54.0 | Mean Test Rewards:  73.5 |
# | Episode: 420 | Mean Train Rewards:  66.3 | Mean Test Rewards:  85.0 |
# | Episode: 430 | Mean Train Rewards:  61.5 | Mean Test Rewards:  81.2 |
# | Episode: 440 | Mean Train Rewards:  54.2 | Mean Test Rewards:  70.8 |
# | Episode: 450 | Mean Train Rewards:  52.8 | Mean Test Rewards:  89.9 |
# | Episode: 460 | Mean Train Rewards:  71.6 | Mean Test Rewards: 131.0 |
# | Episode: 470 | Mean Train Rewards:  86.8 | Mean Test Rewards: 142.0 |
# | Episode: 480 | Mean Train Rewards: 103.1 | Mean Test Rewards: 134.7 |
# | Episode: 490 | Mean Train Rewards:  88.1 | Mean Test Rewards: 118.5 |
# | Episode: 500 | Mean Train Rewards:  82.9 | Mean Test Rewards: 102.2 |
# | Episode: 510 | Mean Train Rewards:  81.4 | Mean Test Rewards: 103.7 |
# | Episode: 520 | Mean Train Rewards:  84.3 | Mean Test Rewards:  98.8 |
# | Episode: 530 | Mean Train Rewards:  91.6 | Mean Test Rewards: 127.0 |
# | Episode: 540 | Mean Train Rewards:  81.3 | Mean Test Rewards: 127.4 |
# | Episode: 550 | Mean Train Rewards:  83.3 | Mean Test Rewards: 151.5 |
# | Episode: 560 | Mean Train Rewards:  88.5 | Mean Test Rewards: 158.2 |
# | Episode: 570 | Mean Train Rewards:  95.7 | Mean Test Rewards: 153.5 |
# | Episode: 580 | Mean Train Rewards:  93.7 | Mean Test Rewards: 171.6 |
# | Episode: 590 | Mean Train Rewards: 103.7 | Mean Test Rewards: 237.6 |
# | Episode: 600 | Mean Train Rewards: 130.9 | Mean Test Rewards: 276.6 |
# | Episode: 610 | Mean Train Rewards: 141.5 | Mean Test Rewards: 277.4 |
# | Episode: 620 | Mean Train Rewards: 147.0 | Mean Test Rewards: 306.3 |
# | Episode: 630 | Mean Train Rewards: 120.0 | Mean Test Rewards: 246.4 |
# | Episode: 640 | Mean Train Rewards: 109.2 | Mean Test Rewards: 181.7 |
# | Episode: 650 | Mean Train Rewards: 132.6 | Mean Test Rewards: 245.4 |
# | Episode: 660 | Mean Train Rewards: 186.2 | Mean Test Rewards: 338.2 |
# | Episode: 670 | Mean Train Rewards: 183.8 | Mean Test Rewards: 294.7 |
# | Episode: 680 | Mean Train Rewards: 147.1 | Mean Test Rewards: 169.8 |
# | Episode: 690 | Mean Train Rewards: 107.3 | Mean Test Rewards: 101.0 |
# | Episode: 700 | Mean Train Rewards:  77.5 | Mean Test Rewards:  80.0 |
# | Episode: 710 | Mean Train Rewards:  71.2 | Mean Test Rewards:  77.8 |
# | Episode: 720 | Mean Train Rewards:  83.7 | Mean Test Rewards:  95.6 |
# | Episode: 730 | Mean Train Rewards: 112.0 | Mean Test Rewards: 123.2 |
# | Episode: 740 | Mean Train Rewards: 155.0 | Mean Test Rewards: 162.0 |
# | Episode: 750 | Mean Train Rewards: 181.8 | Mean Test Rewards: 257.6 |
# | Episode: 760 | Mean Train Rewards: 212.2 | Mean Test Rewards: 341.5 |
# | Episode: 770 | Mean Train Rewards: 219.1 | Mean Test Rewards: 382.6 |
# | Episode: 780 | Mean Train Rewards: 229.2 | Mean Test Rewards: 387.8 |
# | Episode: 790 | Mean Train Rewards: 269.0 | Mean Test Rewards: 434.4 |
# | Episode: 800 | Mean Train Rewards: 276.0 | Mean Test Rewards: 364.6 |
# | Episode: 810 | Mean Train Rewards: 237.1 | Mean Test Rewards: 285.0 |
# | Episode: 820 | Mean Train Rewards: 203.0 | Mean Test Rewards: 212.5 |
# | Episode: 830 | Mean Train Rewards: 198.9 | Mean Test Rewards: 207.8 |
# | Episode: 840 | Mean Train Rewards: 234.1 | Mean Test Rewards: 242.1 |
# | Episode: 850 | Mean Train Rewards: 347.2 | Mean Test Rewards: 349.4 |
# | Episode: 860 | Mean Train Rewards: 413.7 | Mean Test Rewards: 442.1 |
# Reached reward threshold in 864 episodes
# | Episode: 864 | Mean Train Rewards: 433.1 | Mean Test Rewards: 477.7 |

# %%
plt.figure(figsize=(12,8))
plt.plot(test_rewards, label='Test Reward')
plt.plot(train_rewards, label='Train Reward')
plt.xlabel('Episode', fontsize=20)
plt.ylabel('Reward', fontsize=20)
plt.hlines(REWARD_THRESHOLD, 0, len(test_rewards), color='r')
plt.legend(loc='lower right')
plt.grid()
